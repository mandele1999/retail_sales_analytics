# %% [markdown]
# ### Step 4: Data Analysis (Descriptve Analysis)
#
# In Data Analysis Step, we’ll connect to the SQLite database, query the data as needed, and then perform various aggregations and analyses.
#
# 1. **Setup and Imports**

# %%
# Import libraries
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style for consistency
sns.set(style="whitegrid")

# %% [markdown]
# 2. **Database Connection and Retrieval**
#
# *Connecting to the SQLite database and load the data into a DataFrame:*

# %%
# Connect to the SQLite database
conn = sqlite3.connect('retail_data.db')

# Query to fetch all data
query = "SELECT * FROM retail_data;"
df = pd.read_sql(query, conn)

# Display first few rows 
df.head()
# Out:
#    Transaction ID                 Date Customer ID  Gender  Age  \
# 0               1  2023-11-24 00:00:00     CUST001    Male   34
# 1               2  2023-02-27 00:00:00     CUST002  Female   26
# 2               3  2023-01-13 00:00:00     CUST003    Male   50
# 3               4  2023-05-21 00:00:00     CUST004    Male   37
# 4               5  2023-05-06 00:00:00     CUST005    Male   30
#
#   Product Category  Quantity  Price per Unit  Total Amount Day of Week  \
# 0           Beauty         3              50           150      Friday
# 1         Clothing         2             500          1000      Monday
# 2      Electronics         1              30            30      Friday
# 3         Clothing         1             500           500      Sunday
# 4           Beauty         2              50           100    Saturday
#
#    Season  Calculated Total
# 0  Autumn               150
# 1  Winter              1000
# 2  Winter                30
# 3  Spring               500
# ...

# %% [markdown]
# 3. **Exploratory Data Analysis**
#
# *Checking data summaries and basic statistics*

# %%
# Display basic information about the DataFrame
df.info()

# Display basic statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
#  9   Day of Week       1000 non-null   object
#  10  Season            1000 non-null   object
#  11  Calculated Total  1000 non-null   int64
# dtypes: int64(6), object(6)
# memory usage: 93.9+ KB
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount  \
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# ...

# %%
# Count and unique frequencies for categorical columns
print(df['Product Category'].value_counts())
print(df['Gender'].value_counts())
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %% [markdown]
# **Visualizations for EDA**:
#
# * Sales Over Time: Visualize trends over the Date column.
# * Product Categories: Show top categories by quantity or revenue.
# * Customer Demographics: Examine trends across Gender.

# %% [markdown]
# **Summary statistics with Box Plots**
#
# To understand distribution and detect any outliers in Quantity, Price per Unit, and Total Amount by observing the range, quartiles, and potential outliers.

# %%
# Box plots for numerical columns
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
sns.boxplot(data=df, y='Quantity', ax=axes[0]).set_title('Quantity Distribution',fontsize=16, fontweight='bold')
sns.boxplot(data=df, y='Price per Unit', ax=axes[1]).set_title('Price per Unit Distribution', fontsize=16, fontweight='bold')
sns.boxplot(data=df, y='Total Amount', ax=axes[2]).set_title('Total Amount Distribution', fontsize=16, fontweight='bold')
# plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation/Interpretation of key areas:**
#
# * Central points `IQR`
# * Spread - `Box Height/variability/IQR`
# * Symmetry and Skewness - `median position`
# * Outliers

# %% [markdown]
# **2. Sales and Transaction Trends Over Time**
#
# To visualize trends in sales and transaction frequency, identify seasonal patterns, and detect any peaks or dips.

# %%
# Monthly sales trend
df['Date'] = pd.to_datetime(df['Date']).dt.tz_localize(None)
monthly_sales = df.set_index('Date')['Total Amount'].resample('M').sum()

# Format the index as "Month Year" (e.g., "Jan 2023")
months_years = monthly_sales.index.strftime('%b %Y').to_numpy()  # '%b' for abbreviated month names, '%Y' for full year

plt.figure(figsize=(10, 5))
plt.plot(months_years, monthly_sales.values, marker='o', color='skyblue', linewidth=2)
plt.title("Monthly Sales Trend", fontsize=16, fontweight='bold')
plt.xlabel("Date", fontsize=12, fontweight='bold')
plt.ylabel("Total Sales", fontsize=12, fontweight='bold')

# Set x-ticks to display every other label(skipping a label to avoid overcrowding)
plt.xticks(range(0, len(months_years), 2), months_years[::2], rotation=45, ha='right')
# plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# **Seasonal Trends**

# %%
# Define a function to map months to seasons
def get_season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'

# Extract the month and create a Season column
df['Month'] = df['Date'].dt.month
df['Season'] = df['Month'].apply(get_season)

# Total sales by season
seasonal_sales = df.groupby('Season')['Total Amount'].sum().reindex(['Winter', 'Spring', 'Summer', 'Fall'])

# Bar chart of sales by season
seasonal_sales.plot(kind='bar', color='dodgerblue', edgecolor='white', figsize=(8, 5))
plt.title("Total Sales by Season", fontsize=16, fontweight='bold')
plt.xlabel("Season", fontsize=12, fontweight='bold')
plt.ylabel("Total Sales", fontsize=12, fontweight='bold')
plt.xticks(rotation=0)
plt.show()

# Box plot to view sales distribution per season
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Season', y='Total Amount', order=['Winter', 'Spring', 'Summer', 'Fall'], palette="viridis")
plt.title("Sales Distribution by Season", fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# **3. Customer Demographics**
#
# To show the proportion of sales by gender and examine spending behavior by customer segment.

# %%
# Gender distribution in sales
gender_sales = df.groupby('Gender')['Total Amount'].sum()
gender_sales.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(6, 6), title="Sales by Gender") #ttitle param left on purpose/can work without
plt.title("Sales by Gender", fontsize=16, fontweight='bold')
plt.ylabel("")  # Remove the y-axis label
plt.show()

# Average spending per customer
avg_spend = df.groupby('Customer ID')['Total Amount'].mean()
avg_spend.hist(bins=20, color='teal', edgecolor='white')
plt.title("Average Spend per Customer", fontsize=16, fontweight='bold')
plt.xlabel("Average Spend", fontsize=12, fontweight='bold')
plt.ylabel("Frequency", fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# 4. **Top Selling Product Categories**
#
# Identify the most popular and profitable product categories

# %%
# Top-selling categories by total sales
category_sales = df.groupby('Product Category')['Total Amount'].sum().sort_values()
category_sales.plot(kind='barh', color='teal', figsize=(8, 6), title="Sales by Product Category")
plt.xlabel("Total Sales")
plt.ylabel("Product Category")
#plt.xticks(rotation=45)
plt.show()

# Reformat the data to use Seaborn for a grouped bar plot
price_dist = df.groupby(['Product Category', 'Price per Unit']).size().reset_index(name='Count')

# Create the grouped bar plot
plt.figure(figsize=(12, 6))
sns.barplot(data=price_dist, x='Price per Unit', y='Count', hue='Product Category', dodge=True)

# Set labels and title
plt.title("Price Distribution per Category", fontsize=16, fontweight='bold')
plt.xlabel("Price per Unit", fontsize=13, fontweight='bold')
plt.ylabel("Count", fontsize=13, fontweight='bold')
plt.xticks(rotation=0)


# Increase y-axis limit for extra space
max_count = price_dist['Count'].max()
plt.ylim(0, max_count + 20) 

plt.show()

# Price distribution per category
price_dist = df.groupby('Product Category')['Price per Unit'].value_counts()
price_dist.plot(kind='barh', figsize=(8, 6), title="Price Distribution per Category")
plt.xlabel("Price Distribution")
plt.ylabel("Product Category, Prices")
#plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 5. **Purchase Patterns**
#
# Analyze average purchase quantities and transaction frequency to understand customer behavior.

# %%
# Average quantity per transaction
df['Quantity'].hist(bins=15, color='lightgreen', edgecolor='black')
plt.title("Quantity per Transaction")
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()

# Transaction frequency per customer
transaction_frequency = df['Customer ID'].value_counts()
transaction_frequency.plot(kind='hist', bins=20, color='salmon', edgecolor='black')
plt.title("Transaction Frequency per Customer")
plt.xlabel("Number of Transactions")
plt.ylabel("Customer Count")
plt.show()

# %%
# Highest Spending Customers
top_customers = df.groupby('Customer ID')['Total Amount'].sum().sort_values(ascending=False).head(10)
print("Top 10 Customers by Total Spend:\n", top_customers)
# Out:
# Top 10 Customers by Total Spend:
#  Customer ID
# CUST487    2000
# CUST476    2000
# CUST773    2000
# CUST503    2000
# CUST093    2000
# CUST089    2000
# CUST946    2000
# CUST157    2000
# CUST155    2000
# CUST420    2000
# Name: Total Amount, dtype: int64

# %%
# Close the database connection
conn.close()

# %% [markdown]
# **Explanation of the Analysis Steps**
# * **Sales Over Time**: Visualizes trends in sales over the months or years.
# * **Top Product Categories**: Highlights which categories bring in the most revenue.
# * **Sales by Gender**: Helps understand customer demographics.
# * **Customer Insights**: Identifies top customers or those with high transaction volumes.
# * **Category Trends**: Shows which categories are most popular by quantity sold
